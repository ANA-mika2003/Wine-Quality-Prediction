# %%
#Downloading the dataset from kaggle using opendatasets
# !pip install opendatasets

# %%
import opendatasets as op

# %%
op.download('https://www.kaggle.com/datasets/yasserh/wine-quality-dataset')
# Out:
# Skipping, found downloaded files in ".\wine-quality-dataset" (use force=True to force download)

# %%
import os
directory = '.\wine-quality-dataset'
os.listdir(directory)
# Out:
# ['.ipynb_checkpoints']

# %%
#Importing the dataset
import pandas as pd
dataset = pd.read_csv('WineQT.csv')
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
dataset.shape
# Out:
# (1143, 13)

# %%
dataset=dataset.drop('Id', axis=1)

# %%
dataset.shape
# Out:
# (1143, 12)

# %%
#Identifying the unique number of values in the dataset
dataset.nunique()
# Out:
# fixed acidity            91
# volatile acidity        135
# citric acid              77
# residual sugar           80
# chlorides               131
# free sulfur dioxide      53
# total sulfur dioxide    138
# density                 388
# pH                       87
# sulphates                89
# alcohol                  61
# quality                   6
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 107.3 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
#Analyzing the data through histograms
dataset['fixed acidity'].hist()
# Out:
# <Axes: >

# %%
dataset['volatile acidity'].hist()
# Out:
# <Axes: >

# %%
dataset['citric acid'].hist()
# Out:
# <Axes: >

# %%
dataset['residual sugar'].hist()
# Out:
# <Axes: >

# %%
dataset['chlorides'].hist()
# Out:
# <Axes: >

# %%
dataset['free sulfur dioxide'].hist()
# Out:
# <Axes: >

# %%
dataset['total sulfur dioxide'].hist()
# Out:
# <Axes: >

# %%
dataset['density'].hist()
# Out:
# <Axes: >

# %%
dataset['pH'].hist()
# Out:
# <Axes: >

# %%
dataset['sulphates'].hist()
# Out:
# <Axes: >

# %%
dataset['alcohol'].hist()
# Out:
# <Axes: >

# %%
dataset['quality'].hist()
# Out:
# <Axes: >

# %%
#Splitting the data into target variable and independent variable
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
x
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 6.2  ,  0.6  ,  0.08 , ...,  3.45 ,  0.58 , 10.5  ],
#        [ 5.9  ,  0.55 ,  0.1  , ...,  3.52 ,  0.76 , 11.2  ],
#        [ 5.9  ,  0.645,  0.12 , ...,  3.57 ,  0.71 , 10.2  ]])

# %%
y
# Out:
# array([5, 5, 5, ..., 5, 6, 5], dtype=int64)

# %%
#splitting the arrays into train dataset and test dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.3, random_state=4)

# %%
print(x_train)
x_train.shape
# Out:
# [[ 6.9    0.635  0.17  ...  3.4    0.59  10.3  ]
#  [ 8.9    0.28   0.45  ...  3.25   0.55  12.3  ]
#  [ 8.     0.18   0.37  ...  2.89   0.44  12.7  ]
#  ...
#  [ 8.9    0.32   0.31  ...  3.17   0.55  10.4  ]
#  [ 8.2    0.56   0.23  ...  3.28   0.62   9.4  ]
#  [ 7.3    0.66   0.    ...  3.61   0.96   9.9  ]]
# (800, 11)

# %%
print(x_test)
x_test.shape
# Out:
# [[10.2   0.44  0.58 ...  3.29  0.99 12.  ]
#  [10.3   0.41  0.42 ...  3.19  0.62  9.5 ]
#  [11.5   0.45  0.5  ...  3.26  1.11 11.  ]
#  ...
#  [ 8.2   0.73  0.21 ...  3.2   0.52  9.5 ]
#  [ 7.6   0.42  0.25 ...  3.15  0.57  9.1 ]
#  5 5 6 7 6 5 6 7 5 6 6 6 6 5 5 7 6 6 6 7 6 6 5 7 7 6 5 5 4 6 5 5 6 5 6 7 3
#  6 7 6 6 6 6 6 6 5 6 7 5 5 5 6 6 7 6 6 6 5 5 5 6 5 5 6 5 6 6 4 4 5 5 6 5 7
#  6 5 6 5 5 7 5 5 7 6 6 6 5 6 7 6 5 6 6 6 7 5 7 6 5 5 6 6 5 6 5 5 6 5 6 6 5
#  6 5 5 5 6 5 6 5 5 5]
# (343,)

# %%
#training the linear regression model using the training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
# array([[10.2 ,  0.44,  0.58, ...,  3.29,  0.99, 12.  ],
#        [10.3 ,  0.41,  0.42, ...,  3.19,  0.62,  9.5 ],
#        [11.5 ,  0.45,  0.5 , ...,  3.26,  1.11, 11.  ],
#        ...,
#        [ 8.2 ,  0.73,  0.21, ...,  3.2 ,  0.52,  9.5 ],
#        [ 7.6 ,  0.42,  0.25, ...,  3.15,  0.57,  9.1 ],
#        [ 9.2 ,  0.92,  0.24, ...,  3.48,  0.54,  9.8 ]])

# %%
#predicting the test results
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([6.52487742, 5.36496165, 6.37113769, 4.94177393, 5.41571637,
#        5.0274796 , 7.00911731, 6.00067241, 5.5401864 , 5.39224258,
#        6.4286208 , 6.36156447, 5.39743667, 5.18940088, 6.38356674,
#        5.49036067, 5.73094247, 4.98147258, 6.73399167, 6.36638361,
#        5.93906341, 5.99667841, 6.56567959, 5.30212159, 5.26349405,
#        5.49475121, 6.615948  , 5.76447254, 6.52519413, 4.96261883,
#        5.12736329, 5.56350691, 5.74945744, 6.20826496, 6.55946494,
#        5.77756984, 5.8315198 , 5.58504052, 4.78485597, 5.11763604,
#        5.14076022, 4.98084887, 6.9196063 , 4.87786258, 5.69496262,
#        6.18887563, 4.98996261, 5.77845248, 6.16797618, 6.12776246,
#        4.89897798, 5.80663102, 5.59938682, 5.43792832, 5.41362526,
#        6.04356488, 5.78785063, 5.64002432, 6.30086184, 5.59776626,
#        5.71284169, 5.3671109 , 6.2355462 , 5.60530675, 6.14241971,
#        5.84175979, 5.83561104, 5.25964913, 5.48647716, 5.62314762,
# ...

# %%
y_pred.shape
# Out:
# (343,)

# %%
y_test
# Out:
# array([7, 6, 6, 5, 5, 5, 6, 6, 5, 5, 7, 6, 5, 6, 6, 5, 6, 5, 8, 6, 6, 5,
#        6, 5, 5, 5, 7, 5, 7, 5, 5, 5, 5, 6, 7, 6, 5, 6, 4, 5, 5, 6, 6, 6,
#        6, 7, 5, 6, 5, 7, 5, 5, 6, 5, 5, 6, 6, 5, 6, 6, 6, 6, 6, 5, 6, 6,
#        6, 4, 6, 5, 7, 5, 6, 7, 6, 5, 6, 5, 5, 5, 5, 5, 6, 5, 6, 6, 6, 5,
#        5, 6, 5, 7, 4, 5, 6, 5, 6, 5, 5, 6, 5, 5, 8, 6, 5, 6, 7, 5, 7, 6,
#        5, 6, 6, 5, 6, 5, 6, 6, 7, 5, 6, 5, 5, 7, 6, 6, 5, 6, 3, 6, 6, 5,
#        5, 6, 4, 6, 5, 6, 5, 7, 5, 5, 5, 6, 5, 6, 6, 6, 5, 6, 6, 5, 6, 5,
#        8, 7, 5, 8, 6, 6, 6, 5, 6, 5, 7, 6, 6, 5, 6, 5, 5, 5, 6, 5, 8, 5,
#        5, 6, 6, 5, 5, 5, 6, 4, 6, 5, 6, 6, 5, 5, 6, 7, 5, 5, 6, 5, 5, 5,
#        5, 5, 6, 6, 5, 7, 5, 6, 5, 5, 6, 7, 5, 5, 6, 7, 4, 5, 5, 7, 6, 6,
#        5, 6, 5, 5, 6, 7, 6, 5, 6, 7, 5, 6, 6, 6, 6, 5, 5, 7, 6, 6, 6, 7,
#        6, 6, 5, 7, 7, 6, 5, 5, 4, 6, 5, 5, 6, 5, 6, 7, 3, 6, 7, 6, 6, 6,
#        6, 6, 6, 5, 6, 7, 5, 5, 5, 6, 6, 7, 6, 6, 6, 5, 5, 5, 6, 5, 5, 6,
# ...

# %%
print(type(y_pred))
print(y_train[50])
print(y_test[50])
print(y_pred[50])
# Out:
# <class 'numpy.ndarray'>
# 6
# 5
# 4.898977978571596

# %%
print(type(y_pred))
print(y_train[150])
print(y_test[150])
print(y_pred[150])
# Out:
# <class 'numpy.ndarray'>
# 5
# 6
# 6.058175697050796

# %%
print(type(y_pred))
print(y_train[:5])
print(y_test[:5])
print(y_pred[:5])
# Out:
# <class 'numpy.ndarray'>
# [6 7 6 5 7]
# [7 6 6 5 5]
# [6.52487742 5.36496165 6.37113769 4.94177393 5.41571637]

# %%
import matplotlib.pyplot as plt

# %%
len(x_train)
# Out:
# 800

# %%
len(y_train)
# Out:
# 800

# %%
x_train.shape
# Out:
# (800, 11)

# %%
y_train.shape
# Out:
# (800,)

# %%
#visualizing the training set results
for i in range(x.shape[1]):  
    plt.scatter(x_train[:, i],y_train, label=f'Column {i}')

#plt.plot(x_train[:len(regressor.predict(x_train))], regressor.predict(x_train), marker='x')

plt.title('Wine Quality- Training set')
plt.xlabel('Characteristics')
plt.ylabel('Quality')
plt.legend()
plt.show()

# %%
#visualizing the test set results
for i in range(x.shape[1]): 
    plt.scatter(x_test[:, i], y_test,label=f'Column {i} ')

#plt.plot(x_test[:len(y_pred)],y_pred, marker='x')

plt.title('Wine Quality-Test Set')
plt.xlabel('Characteristics')
plt.ylabel('actual Quality')
plt.legend()
plt.show()

# %%
#visualizing the predicted results
for i in range(x.shape[1]): 
    plt.scatter(x_test[:, i], y_pred,label=f'Column {i} ')
    
plt.title('Wine Quality-Predicted')
plt.xlabel('Characteristics')
plt.ylabel('predicted Quality')
plt.legend()
plt.show()

# %%
#The values in the above plot are distributed equally around zero. Hence,Linear Assumption is satisfied.

# %%
#obtaining the linear regression equation with the values of coefficients
print(regressor.coef_)
# Out:
# [ 3.19614021e-02 -1.19642758e+00 -4.00076949e-01 -2.56709360e-03
#  -1.97932082e+00  4.94685786e-03 -3.58905485e-03 -3.65872382e+00
#  -5.32914790e-01  8.41888785e-01  3.09479063e-01]

# %%
print(regressor.intercept_)
# Out:
# 8.037153434817636
